# %% [markdown]
# <a href="https://colab.research.google.com/github/Trangng320/Tri-Tue-Nhan-Tao/blob/main/Nh%E1%BA%ADn_di%E1%BB%87n_%C4%91%E1%BB%93_%C4%83n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Khai báo và sử dụng các thư viện sau
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import SGD, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/BTVN/Food
# Out:
# /content/drive/MyDrive/Colab Notebooks/BTVN/Food

# %%
# Tạo ra class ImageDataGenerator để chỉnh ảnh 
train_datagen=ImageDataGenerator(rescale=1/255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
# Tạo bộ dữ liệu training set
training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/BTVN/Food/Train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 3008 images belonging to 10 classes.

# %%
validation=train_datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/BTVN/Food/Validation',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 60 images belonging to 10 classes.

# %%
training_set.class_indices
# Out:
# {'Banh cuon': 0,
#  'Banh mi': 1,
#  'Banh pia': 2,
#  'Banh tet': 3,
#  'Banh xeo': 4,
#  'Bun dau mam tom': 5,
#  'Ca kho to': 6,
#  'Com tam': 7,
#  'Nem': 8,
#  'Pho': 9}

# %%
validation.class_indices
# Out:
# {'Banh cuon': 0,
#  'Banh mi': 1,
#  'Banh pia': 2,
#  'Banh tet': 3,
#  'Banh xeo': 4,
#  'Bun dau mam tom': 5,
#  'Ca kho to': 6,
#  'Com tam': 7,
#  'Nem': 8,
#  'Pho': 9}

# %%
# Tạo ra mạng CNN để train mô hình
model=Sequential()
# Tích chập 32 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) 
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))
# Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))
# Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))
# Duỗi thẳng dữ liệu 
model.add(Flatten())
# Tạo lớp ẩn thứ nhất với 128 tín hiệu ra
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
# Tạo lớp ẩn thứ hai với 3 tín hiệu ra
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 150, 150, 32)      896
#
#  conv2d_7 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d_3 (MaxPooling  (None, 75, 75, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_9 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 37, 37, 128)       73856
#
#  conv2d_11 (Conv2D)          (None, 37, 37, 128)       147584
#
#  max_pooling2d_5 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten_1 (Flatten)         (None, 41472)             0
#
#  dense_2 (Dense)             (None, 128)               5308544
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 5,596,842
# Trainable params: 5,596,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Biên dịch 
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
# Gán biến lại để vẽ đồ thị, với 500 lần học (epochs), mỗi lần học thì chỉ học␣128 dữ liệu (batch_size), khi sai số không thay đổi trong 20 lần học thì sẽ␣ dừng học 
history=model.fit(training_set,epochs=20,batch_size=128,verbose=1, validation_data=validation, callbacks=[EarlyStopping(monitor='val_loss', patience=30)])
# Out:
# Epoch 1/20
# 94/94 [==============================] - 62s 654ms/step - loss: 2.7262 - accuracy: 0.1320 - val_loss: 2.2949 - val_accuracy: 0.1333
# Epoch 2/20
# 94/94 [==============================] - 61s 648ms/step - loss: 2.2468 - accuracy: 0.1592 - val_loss: 1.9915 - val_accuracy: 0.2667
# Epoch 3/20
# 94/94 [==============================] - 61s 645ms/step - loss: 2.0356 - accuracy: 0.2593 - val_loss: 1.7221 - val_accuracy: 0.3833
# Epoch 4/20
# 94/94 [==============================] - 61s 651ms/step - loss: 1.8180 - accuracy: 0.3614 - val_loss: 1.3247 - val_accuracy: 0.5167
# Epoch 5/20
# 94/94 [==============================] - 61s 646ms/step - loss: 1.6648 - accuracy: 0.4358 - val_loss: 1.3439 - val_accuracy: 0.5333
# Epoch 6/20
# 94/94 [==============================] - 61s 639ms/step - loss: 1.5388 - accuracy: 0.4781 - val_loss: 1.2240 - val_accuracy: 0.6000
# Epoch 7/20
# 94/94 [==============================] - 61s 645ms/step - loss: 1.3886 - accuracy: 0.5289 - val_loss: 0.9118 - val_accuracy: 0.6667
# Epoch 8/20
# 94/94 [==============================] - 60s 637ms/step - loss: 1.3288 - accuracy: 0.5452 - val_loss: 0.9205 - val_accuracy: 0.6667
# Epoch 9/20
# 94/94 [==============================] - 60s 640ms/step - loss: 1.1733 - accuracy: 0.6124 - val_loss: 0.8536 - val_accuracy: 0.7333
# Epoch 10/20
# 94/94 [==============================] - 60s 637ms/step - loss: 1.0450 - accuracy: 0.6446 - val_loss: 0.6086 - val_accuracy: 0.7667
# Epoch 11/20
# 94/94 [==============================] - 60s 637ms/step - loss: 0.9520 - accuracy: 0.6745 - val_loss: 0.4918 - val_accuracy: 0.8167
# Epoch 12/20
# 94/94 [==============================] - 61s 654ms/step - loss: 0.8794 - accuracy: 0.7025 - val_loss: 0.7823 - val_accuracy: 0.7167
# Epoch 13/20
# 94/94 [==============================] - 60s 640ms/step - loss: 0.8465 - accuracy: 0.7204 - val_loss: 0.7536 - val_accuracy: 0.7167
# Epoch 14/20
# 94/94 [==============================] - 60s 635ms/step - loss: 0.7519 - accuracy: 0.7533 - val_loss: 0.3783 - val_accuracy: 0.8500
# Epoch 15/20
# 94/94 [==============================] - 59s 632ms/step - loss: 0.6818 - accuracy: 0.7779 - val_loss: 0.4708 - val_accuracy: 0.8333
# Epoch 16/20
# 94/94 [==============================] - 60s 635ms/step - loss: 0.6065 - accuracy: 0.8025 - val_loss: 0.3180 - val_accuracy: 0.8667
# Epoch 17/20
# 94/94 [==============================] - 60s 640ms/step - loss: 0.5957 - accuracy: 0.8025 - val_loss: 0.5831 - val_accuracy: 0.8167
# Epoch 18/20
# 94/94 [==============================] - 60s 638ms/step - loss: 0.5420 - accuracy: 0.8115 - val_loss: 0.3149 - val_accuracy: 0.9167
# Epoch 19/20
# 94/94 [==============================] - 60s 636ms/step - loss: 0.4405 - accuracy: 0.8554 - val_loss: 0.2406 - val_accuracy: 0.8667
# Epoch 20/20
# 94/94 [==============================] - 60s 635ms/step - loss: 0.4486 - accuracy: 0.8517 - val_loss: 0.2840 - val_accuracy: 0.9167

# %%
# Đánh giá độ chính xác của mô hình 
Score=model.evaluate(training_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 0.25938165187835693
# Train Accuracy 0.9212101101875305

# %%
# Lưu lại
model.save("Food.h5")

# %%
# Tải mô hình 
model_CNN=load_model('Food.h5')

# %%
Test = "/content/drive/MyDrive/Colab Notebooks/BTVN/Food/Test"
for i in os.listdir(Test):
  img=load_img(Test+'/'+i,target_size=(150,150))
  plt.imshow(img)
  img=img_to_array(img)
  img=img.astype('float32')
  img=img/255
  img=np.expand_dims(img,axis=0)
  result=model_CNN.predict(img)
  if round(result[0][0])==1:
    prediction='banh cuon'
  if round(result[0][1])==1:
    prediction='banh mi'
  if round(result[0][2])==1:
    prediction='banh pia'
  if round(result[0][3])==1:
    prediction='banh tet'
  if round(result[0][4])==1:
    prediction='banh xeo'
  if round(result[0][5])==1:
    prediction='bun dau mam tom'
  if round(result[0][6])==1:
    prediction='ca kho to'
  if round(result[0][7])==1:
    prediction='com tam'
  if round(result[0][8])==1:
    prediction='nem'
  if round(result[0][9])==1:
    prediction='pho'
  print(prediction)
  plt.show()
# Out:
# 1/1 [==============================] - 0s 16ms/step
# banh cuon
# 1/1 [==============================] - 0s 16ms/step
# banh mi
# 1/1 [==============================] - 0s 16ms/step
# banh pia
# 1/1 [==============================] - 0s 17ms/step
# banh tet
# 1/1 [==============================] - 0s 17ms/step
# bun dau mam tom
# 1/1 [==============================] - 0s 15ms/step
# com tam
# 1/1 [==============================] - 0s 71ms/step
# nem
# 1/1 [==============================] - 0s 15ms/step
# pho
# 1/1 [==============================] - 0s 15ms/step
# banh xeo
# 1/1 [==============================] - 0s 17ms/step
# ca kho to

# %%
# !jupyter nbconvert --to html "/Nhận_diện_đồ_ăn.ipynb"
# Out:
# [NbConvertApp] Converting notebook /Nhận_diện_đồ_ăn.ipynb to html
# [NbConvertApp] Writing 1676437 bytes to /Nhận_diện_đồ_ăn.html
