# %% [markdown]
# <a href="https://colab.research.google.com/github/Trangng320/Tri-Tue-Nhan-Tao/blob/main/Nh%E1%BA%ADn_di%E1%BB%87n_ti%E1%BB%81n_Vi%E1%BB%87t_Nam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Khai báo và sử dụng các thư viện sau
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import SGD, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/BTVN/TienVN
# Out:
# /content/drive/MyDrive/Colab Notebooks/BTVN/TienVN

# %%
# Tạo ra class ImageDataGenerator để chỉnh ảnh 
train_datagen=ImageDataGenerator(rescale=1/255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
# Tạo bộ dữ liệu training set
training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/BTVN/TienVN/Train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 794 images belonging to 9 classes.

# %%
validation=train_datagen.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/BTVN/TienVN/Validation',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 50 images belonging to 9 classes.

# %%
training_set.class_indices
# Out:
# {'100K': 0,
#  '10k': 1,
#  '1k': 2,
#  '200k': 3,
#  '20k': 4,
#  '2k': 5,
#  '500k': 6,
#  '50K': 7,
#  '5k': 8}

# %%
validation.class_indices
# Out:
# {'100k': 0,
#  '10k': 1,
#  '1k': 2,
#  '200k': 3,
#  '20k': 4,
#  '2k': 5,
#  '500k': 6,
#  '50k': 7,
#  '5k': 8}

# %%
# Tạo ra mạng CNN để train mô hình
model=Sequential()
# Tích chập 32 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) 
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))
# Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))
# Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) 
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
# Lấy phần tử lớn nhất ở trong 2 hàng và 2 cột
model.add(MaxPooling2D(2,2))
# Duỗi thẳng dữ liệu 
model.add(Flatten())
# Tạo lớp ẩn thứ nhất với 128 tín hiệu ra
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
# Tạo lớp ẩn thứ hai với 3 tín hiệu ra
model.add(Dense(9,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 128)               5308544
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 5,596,713
# Trainable params: 5,596,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Biên dịch 
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
# Gán biến lại để vẽ đồ thị, với 500 lần học (epochs), mỗi lần học thì chỉ học␣128 dữ liệu (batch_size), khi sai số không thay đổi trong 20 lần học thì sẽ␣ dừng học 
history=model.fit(training_set,epochs=100,batch_size=128,verbose=1, validation_data=validation, callbacks=[EarlyStopping(monitor='val_loss', patience=30)])
# Out:
# Epoch 1/100
# 25/25 [==============================] - 24s 954ms/step - loss: 0.1317 - accuracy: 0.9685 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 2/100
# 25/25 [==============================] - 16s 638ms/step - loss: 0.1265 - accuracy: 0.9622 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 3/100
# 25/25 [==============================] - 17s 666ms/step - loss: 0.0881 - accuracy: 0.9710 - val_loss: 0.0188 - val_accuracy: 1.0000
# Epoch 4/100
# 25/25 [==============================] - 17s 679ms/step - loss: 0.1379 - accuracy: 0.9584 - val_loss: 0.0496 - val_accuracy: 0.9600
# Epoch 5/100
# 25/25 [==============================] - 17s 668ms/step - loss: 0.1074 - accuracy: 0.9622 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 6/100
# 25/25 [==============================] - 17s 681ms/step - loss: 0.0391 - accuracy: 0.9836 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 7/100
# 25/25 [==============================] - 16s 623ms/step - loss: 0.0599 - accuracy: 0.9786 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 8/100
# 25/25 [==============================] - 16s 624ms/step - loss: 0.0962 - accuracy: 0.9710 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 9/100
# 25/25 [==============================] - 16s 623ms/step - loss: 0.0484 - accuracy: 0.9824 - val_loss: 0.0128 - val_accuracy: 1.0000
# Epoch 10/100
# 25/25 [==============================] - 17s 678ms/step - loss: 0.0715 - accuracy: 0.9786 - val_loss: 0.0449 - val_accuracy: 0.9800
# Epoch 11/100
# 25/25 [==============================] - 16s 634ms/step - loss: 0.0910 - accuracy: 0.9647 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 12/100
# 25/25 [==============================] - 16s 630ms/step - loss: 0.0842 - accuracy: 0.9811 - val_loss: 0.0535 - val_accuracy: 0.9600
# Epoch 13/100
# 25/25 [==============================] - 17s 700ms/step - loss: 0.1380 - accuracy: 0.9559 - val_loss: 0.0296 - val_accuracy: 0.9800
# Epoch 14/100
# 25/25 [==============================] - 16s 622ms/step - loss: 0.1139 - accuracy: 0.9622 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch
-04 - val_accuracy: 1.0000
# Epoch 52/100
# 25/25 [==============================] - 17s 666ms/step - loss: 0.0365 - accuracy: 0.9861 - val_loss: 0.0189 - val_accuracy: 0.9800
# Epoch 53/100
# 25/25 [==============================] - 16s 625ms/step - loss: 0.0751 - accuracy: 0.9798 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 54/100
# 25/25 [==============================] - 16s 621ms/step - loss: 0.0379 - accuracy: 0.9874 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 55/100
# 25/25 [==============================] - 17s 670ms/step - loss: 0.0434 - accuracy: 0.9824 - val_loss: 4.5784e-04 - val_accuracy: 1.0000
# Epoch 56/100
# 25/25 [==============================] - 15s 609ms/step - loss: 0.0388 - accuracy: 0.9887 - val_loss: 9.2822e-04 - val_accuracy: 1.0000
# Epoch 57/100
# 25/25 [==============================] - 15s 618ms/step - loss: 0.0636 - accuracy: 0.9736 - val_loss: 0.0152 - val_accuracy: 1.0000
# Epoch 58/100
# 25/25 [==============================] - 15s 611ms/step - loss: 0.1006 - accuracy: 0.9647 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 59/100
# 25/25 [==============================] - 17s 663ms/step - loss: 0.0597 - accuracy: 0.9786 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 60/100
# 25/25 [==============================] - 16s 625ms/step - loss: 0.0423 - accuracy: 0.9824 - val_loss: 0.0155 - val_accuracy: 0.9800
# Epoch 61/100
# 25/25 [==============================] - 16s 622ms/step - loss: 0.0492 - accuracy: 0.9773 - val_loss: 0.0595 - val_accuracy: 0.9800
# Epoch 62/100
# 25/25 [==============================] - 17s 666ms/step - loss: 0.0867 - accuracy: 0.9673 - val_loss: 0.0106 - val_accuracy: 1.0000
# Epoch 63/100
# 25/25 [==============================] - 15s 616ms/step - loss: 0.0463 - accuracy: 0.9811 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 64/100
# 25/25 [==============================] - 15s 608ms/step - loss: 0.0462 - accuracy: 0.9798 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 65/100
# 25/25 [==============================] - 15s 609ms/step - loss: 0.0882 - accuracy: 0.9748 - val_loss: 0.0565 - val_accuracy: 0.9800
# Epoch 66/100
# 25/25 [==============================] - 17s 663ms/step - loss: 0.0628 - accuracy: 0.9786 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 67/100
# 25/25 [==============================] - 17s 666ms/step - loss: 0.0530 - accuracy: 0.9798 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 68/100
# 25/25 [==============================] - 15s 612ms/step - loss: 0.0456 - accuracy: 0.9836 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 69/100
# 25/25 [==============================] - 16s 658ms/step - loss: 0.0435 - accuracy: 0.9836 - val_loss: 0.2731 - val_accuracy: 0.9800
# Epoch 70/100
# 25/25 [==============================] - 15s 615ms/step - loss: 0.0643 - accuracy: 0.9773 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 71/100
# 25/25 [==============================] - 16s 618ms/step - loss: 0.0631 - accuracy: 0.9824 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 72/100
# 25/25 [==============================] - 15s 611ms/step - loss: 0.0442 - accuracy: 0.9798 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 73/100
# 25/25 [==============================] - 16s 658ms/step - loss: 0.0553 - accuracy: 0.9824 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 74/100
# 25/25 [==============================] - 15s 604ms/step - loss: 0.0762 - accuracy: 0.9786 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 75/100
# 25/25 [==============================] - 15s 601ms/step - loss: 0.0793 - accuracy: 0.9685 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 76/100
# 25/25 [==============================] - 16s 651ms/step - loss: 0.1021 - accuracy: 0.9736 - val_loss: 0.0135 - val_accuracy: 1.0000
# Epoch 77/100
# 25/25 [==============================] - 15s 604ms/step - loss: 0.0678 - accuracy: 0.9773 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 78/100
# 25/25 [==============================] - 15s 602ms/step - loss: 0.0543 - accuracy: 0.9786 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 79/100
# 25/25 [==============================] - 15s 613ms/step - loss: 0.0420 - accuracy: 0.9849 - val_loss: 0.0365 - val_accuracy: 0.9800
# Epoch 80/100
# 25/25 [==============================] - 16s 645ms/step - loss: 0.0667 - accuracy: 0.9811 - val_loss: 0.0045 - val_accuracy: 1.0000

# %%
# Đánh giá độ chính xác của mô hình 
Score=model.evaluate(training_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 0.01864953711628914
# Train Accuracy 0.996221661567688

# %%
# Lưu lại
model.save("TienVN.h5")

# %%
# Tải mô hình 
model_CNN=load_model('TienVN.h5')

# %%
Test = "/content/drive/MyDrive/Colab Notebooks/BTVN/TienVN/Test"
for i in os.listdir(Test):
  img=load_img(Test+'/'+i,target_size=(150,150))
  plt.imshow(img)
  img=img_to_array(img)
  img=img.astype('float32')
  img=img/255
  img=np.expand_dims(img,axis=0)
  result=model_CNN.predict(img)
  if round(result[0][0])==1:
    prediction='100k'
  if round(result[0][1])==1:
    prediction='10k'
  if round(result[0][2])==1:
    prediction='1k'
  if round(result[0][3])==1:
    prediction='200k'
  if round(result[0][4])==1:
    prediction='20k'
  if round(result[0][5])==1:
    prediction='2k'
  if round(result[0][6])==1:
    prediction='500k'
  if round(result[0][7])==1:
    prediction='50k'
  if round(result[0][8])==1:
    prediction='5k'
  print(prediction)
  plt.show()
# Out:
# 1/1 [==============================] - 0s 323ms/step
# 200k
# 1/1 [==============================] - 0s 16ms/step
# 50k
# 1/1 [==============================] - 0s 16ms/step
# 2k
# 1/1 [==============================] - 0s 22ms/step
# 10k
# 1/1 [==============================] - 0s 18ms/step
# 20k
# 1/1 [==============================] - 0s 17ms/step
# 100k
# 1/1 [==============================] - 0s 16ms/step
# 500k
# 1/1 [==============================] - 0s 20ms/step
# 5k
